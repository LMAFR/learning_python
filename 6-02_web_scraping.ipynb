# %% [markdown]
# ### Author: Carmen Alonso Martínez
#
# # Web scraping
#
# Cuando necesitamos extraer información publicada en internet, lo ideal es consultar una API, porque:
#
# * Las respuestas contienen información estructurada
# * En general, el propio servicio nos da documentación sobre cómo hacer peticiones y qué tipo de información podemos solicitar
#
# Pero muchas veces nos encontramos con información en páginas web (en formato [HTML](https://es.wikipedia.org/wiki/HTML)) que nos gustaría obtener, pero sin API disponible.
#
# Estas páginas `HTML` tienen cierta estructura, aunque con ciertos contras:
#
# * Es más compleja, puede tener muchos niveles de anidamiento
# * Es inestable. Están diseñadas para que se vean bien desde el explorador, no para guardar una estructura de consulta. De un día para otro, puede verse alterada por la incorporación de nuevos elementos visuales u otros motivos.
# * Puede ser modificada por código cliente (javascript) en diferentes momentos: al cargar la página, al interaccionar con algún elemento, ...

# %% [markdown]
# ### Ejercicio
#
# Desde tu explorador, consulta el código fuente de una página de tu interés. Por ejemplo, para hacerlo en chrome:
#
# * Accede a la página, p.e. [esta](https://es.wikipedia.org/wiki/HTML).
# * Haz click derecho y pulsa `View page source`. Otra opción es pulsar `Inspect`, que además abrirá las herramientas de desarrollador de Chrome, muy útiles para navegar por la estructura de la página.

# %% [markdown]
# ## Scraping de elementos html
#
# La librería que vamos a utilizar es [Beautiful Soup](https://pypi.org/project/beautifulsoup4/). Nos permite buscar elementos y navegar por la estructura del html fácilmente.
#
# Vemos dos ejemplos, uno sobre milanuncios y otro sobre spotahome, por si nos _banean_.
#
# ### milanuncios
#
# Imaginemos que queremos comparar precios de un determinado modelo de motocicleta de segunda mano. P.e. con [esta búsqueda](https://www.milanuncios.com/motos-de-carretera/duke-390.htm) en milanuncios.
#
# La mayor parte de las webs con contenido interesante (que hacen negocio gracias a su contenido) intentan protegerlas para evitar que les hagan scraping. Hay varias formas de simular que nuestro script es humano en lugar de un bot, algunas más básicas y otras más complejas. Por ahora, vamos a sobrescribir nuestro _user agent_. Es una cabecera que va en las peticiones diciendo quiénes somos (p.e. qué tipo de explorador usamos). Por defecto, la librería `requests` que vamos a usar, avisa que somos un bot. Vamos a sobrescribir esta cabecera para _disimular_ un poco. Podemos copiar uno popular de (aquí)[https://developers.whatismybrowser.com/useragents/explore/software_type_specific/web-browser/].

# %%
import requests
import bs4 # Para poder comprobar la versión hay que importar el paquete entero.
from bs4 import BeautifulSoup # Aunque realmente lo que nos interesa es esta parte del 
                              # paquete (una vez añadida la línea anterior, esta se podría haber quitado).

# %%
bs4.__version__
# Out:
# '4.9.1'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
} # Definimos este objeto porque no tenemos claro que tipo de header pasa la librería de bs4 a la página cuando pedimos datos.
# Esto se usa para que no reconozca nuestra solicitud como la de un bot, en cuyo caso nos podrían no devolver datos.

# %% [markdown]
# Ahora, nos descargamos el html con `requests`.

# %%
page = requests.get('https://www.milanuncios.com/motos-de-carretera/duke-390.htm', headers=headers)
page
# Out:
# <Response [200]>

# %% [markdown]
# Podemos ver el contenido examinando la propiedad `content`.

# %%
page.content # Esto es todo lo que nos devuelve, pero esto no es manejable. Usamos BeautifulSoup para mejorar cómo se ve esto.
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="es" lang="es">\n<head><title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>\n<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n    <meta name="robots" content="noarchive">\n        <meta name="description" content="Compra venta de motos de carretera de ocasi\xf3n duke 390. Todas las marcas: Aprilia, BMW, Cagiva, Derbi, Honda, Yamaha, Kawasaki, Suzuki">\n<link rel="shortcut icon" href="https://static.milanuncios.com/202012151402-master/favicon.ico">    <link rel="stylesheet" type="text/css" href="https://static.milanuncios.com/202012151402-master/css/estilos.css">\n    <link rel="canonical" href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm" />\n<script src="//c.dcdn.es/borostcf/plugins/BorosTcfAdevintaPlugin.pro.js"></script>\n<script src="//c.dcdn.es/openads/milanuncios/MilanunciosOpenAdsClient.pro.js" defer></script>\n<script type="text/javascript"><!--\nfunction prebu(c){return c;}\nvar esmipri=true;\nvar esmipri2=true;\n// -->\n</script>\n<script async="async" src="https://www.google.com/adsense/search/ads.js"></script>\n<script type="text/javascript" charset="utf-8">\n  (function(g,o){g[o]=g[o]||function(){(g[o][\'q\']=g[o][\'q\']||[]).push(\n  arguments)},g[o][\'t\']=1*new Date})(window,\'_googCsa\');\n</script><script>\n    (function (h, o, t, j, a, r) {\n        h.hj = h.hj || function () {\n                (h.hj.q = h.hj.q || []).push(arguments)\n            };\n        h._hjSettings = {hjid: 566961, hjsv: 5};\n        a = o.getElementsByTagName(\'head\')[0];\n        r = o.createElement(\'script\');\n        r.async = 1;\n        r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;\n        a.appendChild(r);\n    })(window, document, \'//static.hotjar.com/c/hotjar-\', \'.js?sv=\');\n</script>\n<script type="text/javascript" src="https://static.milanuncios.com/202012151402-master/js/jquery-1.12.4.min.js"></script>\n\n<link rel="next" href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm?pagina=2" /></head>    <body lang="ES" class="normal busquedas pub" style="">\n    <div id="htmlContainer">\n\n    <script>\n    (function(){\n        var test = document.createElement(\'div\');\n        test.innerHTML = \'&nbsp;\';\n        test.className = \'adsbox\';\n        document.body.appendChild(test);\n        window.setTimeout(function() {\n            if (test.offsetHeight === 0) {\n                document.body.className = \'normal busquedas pub adbmsg\';\n            }\n            if(typeof test.remove == \'function\'){\n                //If support  is found \n                test.remove()\n            }\n            else{\n                //If not\n               test.outerHTML = \'\';\n            }            \n        }, 100);\n    })();\n    </script>    \n        <div class="contenido ad-Middle ad-Middle-space">\n                    <div class="oas_Top1_wrapper">\n                <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>\n            </div>\n            <div id="oas_Middle1_wrapper" class="ad-Middle-item" style="position: absolute; left: 980px; top: 0">\n                <div id="oas_Middle1" style=""></div>\n            </div>\n            <div id="oas_Middle2_wrapper" class="ad-Middle-item ad-Middle-position">\n                <div id="oas_Middle2"></div>\n            </div>\n                    <div class="cab">\n            <div class="logo">\n                <a href="/" title="segunda mano">\n                    <div></div>\n                </a>\n            </div>\n                            <div class="txtClaim2">\n                                    </div>\n                    <div class="beacrumb-container">\n        <div class="beacrumb">\n            <a href="https://www.milanuncios.com" class="rutenl">Milanuncios</a> &gt;\n                    ...

# %% [markdown]
# Este contenido es solo texto, no tiene estructura. Aún no podemos hacer búsquedas ni navegar por él.
#
# Para hacerlo, creamos una instancia de `Beautiful Soup` y lo parseamos

# %%
soup = BeautifulSoup(page.content, 'html.parser') # Esto pone las cosas un poco más bonitas.

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es" xml:lang="es" xmlns="http://www.w3.org/1999/xhtml">
# <head><title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noarchive" name="robots"/>
# <meta content="Compra venta de motos de carretera de ocasión duke 390. Todas las marcas: Aprilia, BMW, Cagiva, Derbi, Honda, Yamaha, Kawasaki, Suzuki" name="description"/>
# <link href="https://static.milanuncios.com/202012151402-master/favicon.ico" rel="shortcut icon"/> <link href="https://static.milanuncios.com/202012151402-master/css/estilos.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm" rel="canonical">
# <script src="//c.dcdn.es/borostcf/plugins/BorosTcfAdevintaPlugin.pro.js"></script>
# <script defer="" src="//c.dcdn.es/openads/milanuncios/MilanunciosOpenAdsClient.pro.js"></script>
# <script type="text/javascript"><!--
# function prebu(c){return c;}
# var esmipri=true;
# var esmipri2=true;
# // -->
# </script>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
#   (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#   arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# </script><script>
#     (function (h, o, t, j, a, r) {
#         h.hj = h.hj || function () {
#                 (h.hj.q = h.hj.q || []).push(arguments)
#             };
#         h._hjSettings = {hjid: 566961, hjsv: 5};
#         a = o.getElementsByTagName('head')[0];
#         r = o.createElement('script');
#         r.async = 1;
#         r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
# </script>
# <script src="https://static.milanuncios.com/202012151402-master/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm?pagina=2" rel="next"/></link></head> <body class="normal busquedas pub" lang="ES" style="">
# <div id="htmlContainer">
# <script>
#     (function(){
#         var test = document.createElement('div');
#         test.innerHTML = '&nbsp;';
#         test.className = 'adsbox';
#         document.body.appendChild(test);
#         window.setTimeout(function() {
#             if (test.offsetHeight === 0) {
#                 document.body.className = 'normal busquedas pub adbmsg';
#             }
#             if(typeof test.remove == 'function'){
#                 //If support  is found
#                 test.remove()
#             }
#             else{
#                 //If not
#                test.outerHTML = '';
#             }
#         }, 100);
#     })();
#     </script>
# <div class="contenido ad-Middle ad-Middle-space">
# <div class="oas_Top1_wrapper">
# <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>
# </div>
# <div class="ad-Middle-item" id="oas_Middle1_wrapper" style="position: absolute; left: 980px; top: 0">
# <div id="oas_Middle1" style=""></div>
# </div>
# <div class="ad-Middle-item ad-Middle-position" id="oas_Middle2_wrapper">
# <div id="oas_Middle2"></div>
# </div>
# <div class="cab">
# <div class="logo">
# <a href="/" title="segunda mano">
# <div></div>
# </a>
# </div>
# <div class="txtClaim2">
# </div>
# <div class="beacrumb-container">
# <div class="beacrumb">
# <a class="rutenl" href="https://www.milanuncios.com">Milanuncios</a> &gt;
#                             <a class="rutenl" href="/motor/" title="Motor">Motor</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-segunda-mano/" title="Motos de segunda mano">Motos</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-carretera/" title="Motos de carretera">Motos de carretera</a>
# </div>
# </div>
# <script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Milanuncios",
#             "item": "https://www.milanuncios.com"
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Motor",
#             "item": "https://www.milanuncios.com/motor/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Motos",
#             "item": "https://www.milanuncios.com/motos-de-segunda-mano/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Motos de carretera",
#             "item": "https://www.milanuncios.com/motos-de-carretera/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Duke 390",
#             "item": "https://www.milanuncios.com/motos-de-carretera/duke-390.htm"
#         }
#     ]
# }</script>
# </div>
# <div class="contentInnerBox">
# <script src="https://static.milanuncios.com/202012151402-master/js/image_store.js" type="text/javascript"></script>
# <script src="https://static.milanuncios.com/202012151402-master/js/fun.js" type="text/javascript"></script>
# <div id="busgen">
# <div class="bus">
# <noscript>
# <div style="position: absolute; background-color: #880000; color: #FFF">
#             Activa Javascript en tu navegador para poder utilizar milanuncios
#         </div>
# </noscript>
# <script language="JavaScript" type="text/javascript">
#         function enableEmployDemandTypes(value) {
#             if ('s' == value) {
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForFour";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForFour";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForFour";
#                 document.getElementById("employDemand").style.display = "block";
#                 document.getElementById('concv').style.visibility = "visible";
#             }
#             else{
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForThree";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForThree";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForThree";
#                 document.getElementById("employDemand").style.display = "none";
#                 document.getElementById('concv').style.visibility = "hidden";
#             }
#         }
#     </script>
# <div class="busli filtro">
# <div class="busli busli1">
# <select class="cm3" id="ca0" onchange="cabc(this.value)" tabindex="0"><option value="">todas las categorías<option selected="" value="motor">Motor</option><option value="inmobiliaria">Inmobiliaria</option><option value="ofertas-de-empleo">Empleo</option><option value="formacion">Formación y libros</option><option value="servicios">Servicios</option><option value="negocios">Negocios</option><option value="informatica-segunda-mano">Informática</option><option value="imagen-y-sonido">Imagen y Sonido</option><option value="telefonia">Telefonía</option><option value="juegos">Juegos</option><option value="casa-y-jardin">Casa y Jardín</option><option value="moda-y-complementos">Moda y complementos</option><option value="bebes">Bebés</option><option value="aficiones">Aficiones y ocio</option><option value="deportes-nautica">Deportes y náutica</option><option value="mascotas">Mascotas y agricultura</option><option value="comunidad">Comunidad</option></option></select><select class="cm3" id="ca1" onchange="cabc(this.value)" tabindex="1"><option value="">todas las categorías<option value="coches-de-segunda-mano">Coches</option><option value="todoterreno-de-ocasion">Todoterreno</option><option value="remolques">Remolques</option><option value="coches-clasicos">Coches clásicos</option><option value="coches-sin-carnet">Coches sin carnet</option><option value="recambios-y-accesorios">Recambios y accesorios</option><option selected="" value="motos-de-segunda-mano">Motos</option><option value="furgonetas-de-segunda-mano">Furgonetas</option><option value="camiones-usados">Camiones</option><option value="autobuses-usados">Autobuses</option><option value="caravanas-de-segunda-mano">Caravanas</option><option value="autocaravanas-de-segunda-mano">Autocaravanas</option><option value="quads">Quads</option><option value="buggies">Buggies</option><option value="venta-de-karts">Karts</option><option value="tuning">Tuning</option><option value="maquinaria">Maquinaria</option><option value="embarcaciones">Embarcaciones</option><option value="servicios-para-motor">Servicios motor</option><option value="otros-motor">Otros</option></option></select><select class="cm3" id="ca2" onchange="cabc(this.value)" tabindex="2"><option value="motos-de-segunda-mano">todas las categorías<option value="motos-clasicas">Motos clásicas</option><option value="ciclomotores-de-segunda-mano">Ciclomotores</option><option value="scooters-de-segunda-mano">Scooters</option><option selected="" value="motos-de-carretera">Motos de carretera</option><option value="motos-de-cross">Motos de cross</option><option value="minimotos">Minimotos</option><option value="accesorios-para-motos">Accesorios</option><option value="recambios-y-despieces-de-motos">Recambios y despieces</option></option></select><input id="ca3" type="hidden"/> <select class="cm3" id="protmp" onchange="document.getElementById('provincia').value=this.value;loadCities(this, false);" tabindex="5">
# <option value="">en toda España<option value="alava">Álava
#             <option value="albacete">Albacete
#             <option value="alicante">Alicante
#             <option value="almeria">Almería
#             <option data-type="region" value="andalucia">Andalucía
#             <option value="aragon">Aragón
#             <option value="asturias">Asturias
#             <option value="avila">Ávila
#             <option value="badajoz">Badajoz
#             <option value="baleares">Baleares
#             <option value="barcelona">Barcelona
#             <option value="burgos">Burgos
#             <option value="caceres">Cáceres
#             <option value="cadiz">Cádiz
#             <option value="cantabria">Cantabria
#             <option value="canarias">Canarias
#             <option value="castellon">Castellón
#             <option data-type="region" value="castilla_la_mancha">Cast. la Mancha
#             <option data-type="region" value="castilla_y_leon">Cast. y León
#             <option data-type="region" value="catalunya">Catalunya
#             <option value="ceuta">Ceuta
#             <option value="ciudad_real">Ciudad Real
#             <option value="cordoba">Córdoba
#             <option value="cuenca">Cuenca
#             <option data-type="region" value="extremadura">Extremadura
#             <option data-type="region" value="galicia">Galicia
#             <option value="girona">Girona
#             <option value="granada">Granada
#             <option value="guadalajara">Guadalajara
#             <option value="guipuzcoa">Guipúzcoa
#             <option value="huelva">Huelva
#             <option value="huesca">Huesca
#             <option value="jaen">Jaén
#             <option value="la_coruna">La Coruña
#             <option value="la_rioja">La Rioja
#             <option value="las_palmas">Las Palmas
#             <option value="leon">León
#             <option value="lleida">Lleida
#             <option value="lugo">Lugo
#             <option value="madrid">Madrid
#             <option value="malaga">Málaga
#             <option value="melilla">Melilla
#             <option value="murcia">Murcia
#             <option value="navarra">Navarra
#             <option value="ourense">Ourense
#             <option data-type="region" value="pais_vasco">País Vasco
#             <option value="palencia">Palencia
#             <option value="pontevedra">Pontevedra
#             <option value="salamanca">Salamanca
#             <option value="segovia">Segovia
#             <option value="sevilla">Sevilla
#             <option value="soria">Soria
#             <option value="tarragona">Tarragona
#             <option value="tenerife">Tenerife
#             <option value="teruel">Teruel
#             <option value="toledo">Toledo
#             <option value="valencia">Valencia
#             <option data-type="region" value="comunidad_valenciana">Com.Valenciana
#             <option value="valladolid">Valladolid
#             <option value="vizcaya">Vizcaya
#             <option value="zamora">Zamora
#             <option value="zaragoza">Zaragoza
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select> </div>
# <div class="searchAdBox-table-container">
# <div class="searchAdBoxContainer">
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="marca" tabindex="5">
# <option value="">marca
#                 <option value="">TODAS
#                 <option value="Aeon">Aeon
#                 <option value="Adly">Adly
#                 <option value="Alfer">Alfer
#                 <option value="Aprilia">Aprilia
#                 <option value="Atala">Atala
#                 <option value="Bajaj">Bajaj
#                 <option value="Benelli">Benelli
#                 <option value="Beta">Beta
#                 <option value="Bimota">Bimota
#                 <option value="BJR">BJR
#                 <option value="BMW">BMW
#                 <option value="Bombardier">Bombardier
#                 <option value="Buell">Buell
#                 <option value="Bultaco">Bultaco
#                 <option value="Cagiva">Cagiva
#                 <option value="CSR">CSR
#                 <option value="Daelim">Daelim
#                 <option value="Derbi">Derbi
#                 <option value="DKW">DKW
#                 <option value="Ducati">Ducati
#                 <option value="Factory Bike">FactoryBike
#                 <option value="Fantic">Fantic
#                 <option value="Gasgas">Gasgas
#                 <option value="Gilera">Gilera
#                 <option value="Hanway">Hanway
#                 <option value="Harley Davidson">HarleyDavidson
#                 <option value="HM">HM
#                 <option value="Honda">Honda
#                 <option value="HRD">HRD
#                 <option value="Husaberg">Husaberg
#                 <option value="Husqvarna">Husqvarna
#                 <option value="Hyosung">Hyosung
#                 <option value="Indian">Indian
#                 <option value="Italjet">Italjet
#                 <option value="Kawasaki">Kawasaki
#                 <option value="Keeway">Keeway
#                 <option value="KTM">KTM
#                 <option value="Kymco">Kymco
#                 <option value="Lambretta">Lambretta
#                 <option value="Laverda">Laverda
#                 <option value="Leonart">Leonart
#                 <option value="LML">LML
#                 <option value="Malaguti">Malaguti
#                 <option value="MBK">MBK
#                 <option value="Mecatecno">Mecatecno
#                 <option value="Merlin">Merlin
#                 <option value="Mobylette">Mobylette
#                 <option value="Mondial">Mondial
#                 <option value="Montesa">Montesa
#                 <option value="Morini">Morini
#                 <option value="Moto Guzzi">Moto Guzzi
#                 <option value="Motogac">Motogac
#                 <option value="Motor Hispania">MotorHispania
#                 <option value="Muz">Muz
#                 <option value="MV Agusta">MV Agusta
#                 <option value="Ossa">Ossa
#                 <option value="Peugeot">Peugeot
#                 <option value="PGO">PGO
#                 <option value="Piaggio">Piaggio
#                 <option value="Polaris">Polaris
#                 <option value="Puch">Puch
#                 <option value="Renault">Renault
#                 <option value="Rieju">Rieju
#                 <option value="Riya">Riya
#                 <option value="Royal Enfield">RoyalEnfield
#                 <option value="Sanglas">Sanglas
#                 <option value="Scomadi">Scomadi
#                 <option value="Scorpa">Scorpa
#                 <option value="Sherco">Sherco
#                 <option value="Siam">Siam
#                 <option value="Sumco">Sumco
#                 <option value="Suzuki">Suzuki
#                 <option value="Sym">Sym
#                 <option value="TGB">TGB
#                 <option value="TM">TM
#                 <option value="Triumph">Triumph
#                 <option value="Universal Motor">UniversalMotor
#                 <option value="Vem">Vem
#                 <option value="Vespa">Vespa
#                 <option value="Vespino">Vespino
#                 <option value="Victory">Victory
#                 <option value="VOR">VOR
#                 <option value="Yamaha">Yamaha
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <input class="imputs" id="palabras" maxlength="30" onfocus="if(this.value=='modelo')this.value='';" onkeydown="if(event.keyCode==13) cabu();" size="9" style="width:91%" tabindex="6" type="text" value="modelo"/>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="desde" tabindex="7">
# <option value="">Precio desde
#                 <option value="0">0
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="hasta" tabindex="8">
# <option value="">Precio hasta
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anod" tabindex="9">
# <option value="">Año desde</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anoh" tabindex="9">
# <option value="">Año hasta</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="color" tabindex="11">
# <option value="">color
#                 <option value="negr">negro
#                 <option value="azul">azul
#                 <option value="bla">blanco
#                 <option value="gri">gris
#                 <option value="roj">rojo
#                 <option value="plat">plata
#                 <option value="verde">verde
#                 <option value="granate">granate
#                 <option value="amarill">amarillo
#                 <option value="burdeo">burdeos
#                 <option value="oro">oro
#                 <option value="beig">beige
#                 <option value="dorad">dorado
#                 <option value="naranja">naranja
#                 <option value="champan">champan
#                 <option value="marron">marrón
#                 <option value="violeta">violeta
#                 <option value="morad">morado
#                 <option value="crema">crema
#                 <option value="antracita">antracita
#                 <option value="celeste">celeste
#                 <option value="arena">arena
#                 <option value="lila">lila
#                 <option value="bronce">bronce
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="kms" tabindex="12">
# <option value="">km
#                 <option value="200">hasta 200
#                 <option value="400">hasta 400
#                 <option value="600">hasta 600
#                 <option value="800">hasta 800
#                 <option value="1000">hasta 1000
#                 <option value="1500">hasta 1500
#                 <option value="2000">hasta 2000
#                 <option value="2500">hasta 2500
#                 <option value="3000">hasta 3000
#                 <option value="4000">hasta 4000
#                 <option value="5000">hasta 5000
#                 <option value="6000">hasta 6000
#                 <option value="7000">hasta 7000
#                 <option value="10000">hasta 10000
#                 <option value="20000">hasta 20000
#                 <option value="30000">hasta 30000
#                 <option value="40000">hasta 40000
#                 <option value="80000">hasta 80000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="ccd" tabindex="13">
# <option value="">C.C. desde
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="cch" tabindex="14">
# <option value="">C.C.hasta
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="orden" tabindex="15">
# <option value="">ordenar por
#                 <option value="baratos">orden +baratos
#                 <option value="caros">orden +caros
#                 <option value="ano">orden +nuevos
#                 <option value="viejos">orden +antiguos
#                 <option value="kilometraje">ordenar por kilometraje
#             </option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="vendedor" name="vendedor" tabindex="16">
# <option value="">particulares y profesionales
#                 <option value="part">sólo particulares
#                 <option value="prof">sólo profesionales
#             </option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="demanda" tabindex="17">
# <option value="">Oferta y demanda
#                 <option value="n">oferta solo
#                 <option value="s">demanda solo
#             </option></option></option></select>
# </div>
# <input id="cajasbuscaact" type="hidden" value="motos.html"/>
# </div>
# </div>
# </div>
# </div>
# <div class="searchAdBoxFooter"><a class="fillDiv" href="javascript:cabu()" id="vamos" tabindex="85">BUSCAR
#         </a></div>
# <div class="searchAdBoxFooter" style="width:50%; background: #fff; color: #30832F; text-align: center;">
# <span id="searchAdBoxAdCounter"><a href="javascript:cabu()" style="color: #30832F;">BUSCA</a></span>
#          en <h1 class="searchResult">Motos de carretera duke 390</h1> </div>
# <div class="searchAdBoxFooter" style="width:10%; background: #fff; color: #30832F; text-align: left;"> <!--<a href="javascript:resetSearchFilters()">REINICIAR FILTROS</a>--></div>
# <script>
#         if(typeof(ponvalores) != "undefined")
#             ponvalores();
#     </script>
# <input id="cajasbusca" type="hidden" value="defecto.html"/>
# </div>
# <input id="provincia" type="hidden"/>
# <input id="categoria" type="hidden" value="motos-de-carretera"/>
# <input id="primvez" type="hidden" value="si"/>
# <input id="urlb" type="Hidden" value=""/>
# <script type="text/javascript"><!--
#         var modelin = document.getElementById('modelin');
#         if (typeof(modelin) != 'undefined' && modelin != null)
#             modelin.innerHTML = '<input onkeydown="if(event.keyCode==13) cabu();" type=text onfocus="if(this.value==\'modelo\')this.value=\'\';" id="palabras" maxlength="30" size=11 class="imputs" value="modelo" tabindex="6" style="width:86%">';
#     function ponvalores(){
# ponval('palabras', 'duke 390');ponval('provincia',''); ponval('protmp','');
#         loadCities(document.getElementById('protmp'), true);
#
#             }
#     document.addEventListener("DOMContentLoaded", function () {
#         ponvalores();
#     });
# // --></script>
# <script>
#     var jlocdir = "";
#     var jlocalidad = "";
#     var jprovincia='';
#     var textInQueryString = false;
# </script>
# <script src="https://static.milanuncios.com/202012151402-master/js/default_searcher_filters.js"></script> <div id="cuerpo">
# <div id="listing"></div>
# <div style="margin-bottom:4px; text-align: center; clear:both">
# <script type="text/javascript">
#             document.getElementById('searchAdBoxAdCounter').innerHTML = "<span style=\"color: #50545a;\">Encontrados</span>  " +
# 		    "96" + " anuncios <h1 class=\"searchResult\"></h1>" + "<span style=\"color: #50545a;\"></span>";
#         </script>
# </div>
# <div id="AdSMAList1"></div>
# <div class="aditem ProfesionalCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">28 min        </div>
# <div class="x5">
#             r369280246         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-390-369280246.htm" target="_blank">KTM - <b class="sub3">390</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Vigo</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>vigo</div><div class="tx">KTM <b class="sub3">390</b> <b class="sub2">DUKE</b> matriculada septiembre 2020.  NUEVA Cero kilómetros.  Incluye gastos transferencia a nombre del comprador.
# Somos concesionario oficial KTM.  Nuestro horario de 8 a 15: 00 h los jueves de 8 a 21: 00 h ininterrumpido. </div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">4.800<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(1)">
# <div class="pillDiv pillSellerTypePro">Profesional</div>
# </a></div><div class="pillDiv vef"><a href="ktm-390-369280246.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f369280246">
# <a href="javascript:var urlFotos_369280246 = [];urlFotos_369280246['0'] = 'https://img.milanuncios.com/fg/3692/80/369280246_1.jpg?VersionId=xIV0.zrpp4JkzyCqpVfrHqC2cmueJ70x';urlFotos_369280246['1'] = 'https://img.milanuncios.com/fg/3692/80/369280246_2.jpg?VersionId=shIlhqU73IVFA.FvgiN5_XaL1H4Gekue';urlFotos_369280246['2'] = 'https://img.milanuncios.com/fg/3692/80/369280246_3.jpg?VersionId=dzOvhJypSyaEB_wXiFHMlerlDZpoJ4SD';urlFotos_369280246['3'] = 'https://img.milanuncios.com/fg/3692/80/369280246_4.jpg?VersionId=EOLLZiaFn.ZPDtt5nANR6vg7kN5ZQmNs';urlFotos_369280246['4'] = 'https://img.milanuncios.com/fg/3692/80/369280246_5.jpg?VersionId=kNxSYYJJYOFsepeh_up7IAU84VsNDTyo';urlFotos_369280246['5'] = 'https://img.milanuncios.com/fg/3692/80/369280246_6.jpg?VersionId=z8vouwWOcgD3UcBT7hfHysdo8SKcLOJn';urlFotos_369280246['6'] = 'https://img.milanuncios.com/fg/3692/80/369280246_7.jpg?VersionId=2VHCcmZkAUuYdVTNGICAKVV3pbf4rK5J';urlFotos_369280246['7'] = 'https://img.milanuncios.com/fg/3692/80/369280246_8.jpg?VersionId=zqzN5ecSI8aztgIJENGAhU7xG48IS_eS';urlFotos_369280246['8'] = 'https://img.milanuncios.com/fg/3692/80/369280246_9.jpg?VersionId=WWkz9JtYP6LUOZSEV0.Ucoi3p.w2hsuM';ImageStore.addImages(369280246, urlFotos_369280246);openImageDialog('369280246',1,'123456789','https://static.milanuncios.com/202012151402-master/','https://img.milanuncios.com/','urlFotos_369280246')"><img alt="KTM - 390 - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3692/80/369280246_1.jpg?VersionId=hgsogysXER.IIZV9IJdmK.FGc9mqGLJf"/><br/><div class="mini-overlay-superior">9 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">373 cc</div><div class="ano tag-mobile">año 2019</div><div class="gas tag-mobile">gasolina</div> </div>
# </div>
# <div class="aditem-footer" id="ph369280246">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(369280246, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(369280246, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','369280246')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('369280246')"><i class="icon i1 icon-favourite" id="fav369280246"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-369280246" onclick="location.href='/stats/stats-ampliadas.php?id=369280246'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('369280246','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-369280246");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("369280246");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">1 hora        </div>
# <div class="x5">
#             r368051963         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-ktm-duke-390-368051963.htm" target="_blank">KTM - KTM <b class="sub2">DUKE</b> <b class="sub3">390</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Fuente Del Maestre</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Fuente del Maestre</div><div class="tx">Vendo KTM <b class="sub2">Duke</b> <b class="sub3">390</b> con 14. 956 km.
# La moto cuenta con portamatrículas articulado naranja + matrícula metacrilato,  Espejos naranja-carbono,  cubreradiador de reja,  pesas manillar naranjas,  tapas de líquidos de frenos naranjas,  manetas naranjas articuladas,  topes anticaidas naranjas. . . entre otros extras.
# Además cuenta con escape ARROW (silenciador + suppressor),  valorado en 900.
# Cambio de aceite recién hecho y rueda trasera recién cambiada.  Puedo<span class="readMoreHidden" id="readMoreTx-368051963">presentar facturas.
# Podría vender la moto sin ningún extra en 3. 000 (más de 1. 000 en extras).
#
# No leer:  Yamaha,  Kawasaki,  bmw,  Suzuki,  KTM,  triumph,  naked,  benelli, </span><span class="readMoreLink" id="readMoreLink-368051963" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">3.500<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-ktm-duke-390-368051963.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f368051963">
# <a href="javascript:var urlFotos_368051963 = [];urlFotos_368051963['0'] = 'https://img.milanuncios.com/fg/3680/51/368051963_1.jpg?VersionId=sHKQLHU3JRYMY1CLF6yFGsjLpB9_e8Uy';urlFotos_368051963['1'] = 'https://img.milanuncios.com/fg/3680/51/368051963_2.jpg?VersionId=j949mzxUnLMLERZQUd5BEUeeod0.d3GH';urlFotos_368051963['2'] = 'https://img.milanuncios.com/fg/3680/51/368051963_4.jpg?VersionId=D84Iesavm4FkyB_7zfImiPVPwCfbqiVc';urlFotos_368051963['3'] = 'https://img.milanuncios.com/fg/3680/51/368051963_3.jpg?VersionId=.HOyH7Un31phqtr1ox_C7fQCNw3OYwHv';urlFotos_368051963['4'] = 'https://img.milanuncios.com/fg/3680/51/368051963_5.jpg?VersionId=32u.iYlz32.jtftmZLLe5QvDHBPZeWNL';urlFotos_368051963['5'] = 'https://img.milanuncios.com/fg/3680/51/368051963_7.jpg?VersionId=TwiwolkqjEGVmEZ371_ze9QcwWsMUbwf';urlFotos_368051963['6'] = 'https://img.milanuncios.com/fg/3680/51/368051963_6.jpg?VersionId=Y.an8JJFZWiRQAQ1UiqXOnRWHeyK7BvA';urlFotos_368051963['7'] = 'https://img.milanuncios.com/fg/3680/51/368051963_9.jpg?VersionId=7fAg.hJC6w6BJWVJ.ifIfGaJ3SyU3.CK';urlFotos_368051963['8'] = 'https://img.milanuncios.com/fg/3680/51/368051963_8.jpg?VersionId=0BnVDNaWDcjh2d2I6im4lRAULgy.bQ0J';ImageStore.addImages(368051963, urlFotos_368051963);openImageDialog('368051963',1,'124357698','https://static.milanuncios.com/202012151402-master/','https://img.milanuncios.com/','urlFotos_368051963')"><img alt="KTM - KTM DUKE 390 - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3680/51/368051963_1.jpg?VersionId=svqSeRpRjZ94LiIiDHE1kaOQ7VguypGs"/><br/><div class="mini-overlay-superior">9 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2014</div><div class="kms tag-mobile">14.956 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph368051963">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(368051963, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(368051963, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','368051963')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('368051963')"><i class="icon i1 icon-favourite" id="fav368051963"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-368051963" onclick="location.href='/stats/stats-ampliadas.php?id=368051963'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('368051963','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-368051963");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("368051963");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">2 horas        </div>
# <div class="x5">
#             r372487229         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-duke-372487229.htm" target="_blank">KTM - <b class="sub2">DUKE</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Las Palmas De Gran Canaria</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Las Palmas de Gran Canaria</div><div class="tx">Vendo ktm <b class="sub2">duke</b> <b class="sub3">390</b> muy nueva solo 1. 337 km muchos extras aparte se entrega todo lo original garantia oficial valse bike hasta abril 2021 no cambio por nada solo venta interesados por whatsapp. Color naranja</div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">4.500<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-duke-372487229.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f372487229">
# <a href="javascript:var urlFotos_372487229 = [];urlFotos_372487229['0'] = 'https://img.milanuncios.com/fg/3724/87/372487229_1.jpg?VersionId=S.gyHoh7cSakLVvcrUdIJ8LtMaaWDk2a';urlFotos_372487229['1'] = 'https://img.milanuncios.com/fg/3724/87/372487229_2.jpg?VersionId=IQEBDkT7vkMsw_BR2J305OYAsLe5oLUG';urlFotos_372487229['2'] = 'https://img.milanuncios.com/fg/3724/87/372487229_3.jpg?VersionId=yaoNJVT8q9YY6xPZNJqx1roHASu9WuVz';urlFotos_372487229['3'] = 'https://img.milanuncios.com/fg/3724/87/372487229_4.jpg?VersionId=JHMPqRe39GK.zHj_0ohPwbSvJCbRUj37';ImageStore.addImages(372487229, urlFotos_372487229);openImageDialog('372487229',1,'1234','https://static.milanuncios.com/202012151402-master/','https://img.milanuncios.com/','urlFotos_372487229')"><img alt="KTM - DUKE - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3724/87/372487229_1.jpg?VersionId=8e6P_NfRThsyp4qfqfvhrz7U87s.n3jh"/><br/><div class="mini-overlay-superior">4 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2019</div><div class="kms tag-mobile">1.337 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph372487229">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(372487229, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(372487229, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# ...
# <img class="ic_social_footer_hover" src="https://static.milanuncios.com/202012151402-master/imagenes/social/ic-youtube-footer-hover.svg"/>
# <img class="ic_social_footer" src="https://static.milanuncios.com/202012151402-master/imagenes/social/ic-youtube-footer.svg"/>
# </a>
# </div>
# </div> <a href="/legal/condiciones-uso" rel="nofollow" title="Condiciones de uso">CONDICIONES DE USO</a>
#             <a href="/legal/politica-privacidad" rel="nofollow" title="Politica de privacidad">POLÍTICA DE PRIVACIDAD</a>
#             <a href="/legal/politica-cookies" rel="nofollow" title="Politica de cookies">POLÍTICA DE COOKIES</a>
#             <a href="https://ayuda.milanuncios.com/hc/es" rel="nofollow" target="_blank" title="Contactar con milanuncios">CONTACTAR</a>
#             <a href="https://www.milanuncios.com/prensa/?ipromo=home-salaprensa" target="_blank" title="Sala de prensa">SALA DE PRENSA</a>
# </div>
# <div class="footerLinksContainer">
# <div><b>Milanuncios es parte de <a href="https://www.adevinta.com/es/spain" target="_blank" title="Adevinta">Adevinta</a> junto con:</b> </div>
# <ul class="footerLinks">
# <li><a href="https://www.fotocasa.es" target="_blank" title="Fotocasa">fotocasa</a>  </li>
# <li><a href="https://www.habitaclia.com" target="_blank" title="habitaclia.com">habitaclia.com</a>  </li>
# <li><a href="https://www.infojobs.net" target="_blank" title="Infojobs.net">infojobs.net</a>  </li>
# <li><a href="https://www.coches.net" target="_blank" title="Coches.net">coches.net</a>  </li>
# <li><a href="https://motos.coches.net" target="_blank" title="Motos.net">motos.net</a>  </li>
# </ul>
# </div>
# <div class="copyright">Copyright © 2020   Adevinta Spain S.L.U.   Tablón de anuncios gratis</div>
# </div>
# </div>
# </div>
# <div id="wind"></div>
# <script id="tealiumData" type="text/javascript">
#     var utag_data = {"site":"milanuncios","platform":"web","pb_adv_opt":2,"other_filters":null,"more_filters":null,"region_level1_id":null,"region_level1":null,"query":null,"recommendation_id":null,"region_level2_id":null,"region_level2":null,"search_terms":"duke 390","search_id":null,"transaction_id":null,"is_msite":false,"subcategory1":"Motos","subcategory2":"Motos de carretera","subcategory3":null,"user_id":null,"Ads":null,"result_ad_ids":["369280246","368051963","372487229"],"category_id":"10","subcategory1_id":"20","subcategory2_id":"4","subcategory3_id":0,"sell_type":"oferta y demanda","event_name":"list","ads_name_page":"milanuncios\/parrilla","list_type":null,"search_type":null,"channel":"ads","page_list":"list","search_results_position":1,"search_results_number":96,"price_min":0,"price_max":0,"vertical":"motor","page_type":"list","filters":"cat1=Motor:cat2=Motos:cat3=Motos de carretera:palabras=duke 390","event_name_adobe":"ad_impression","ad_publisher_type":"","ad_publisher_type_id":2,"page_category_level1":"Motor","category":"Motor","page_category_level2":"Motos","page_category_level3":"Motos de carretera","page_name":"Motos de carretera duke 390","products":[{"id":"369280246","category":"ads","ad_impression":"1","list_position":1,"highlight_type":"not applicable","list_type":"list"},{"id":"368051963","category":"ads","ad_impression":"1","list_position":2,"highlight_type":"not applicable","list_type":"list"},{"id":"372487229","category":"ads","ad_impression":"1","list_position":3,"highlight_type":"not applicable","list_type":"list"},{"id":"375487542","category":"ads","ad_impression":"1","list_position":4,"highlight_type":"not applicable","list_type":"list"},{"id":"245574293","category":"ads","ad_impression":"1","list_position":5,"highlight_type":"not applicable","list_type":"list"},{"id":"372769202","category":"ads","ad_impression":"1","list_position":6,"highlight_type":"not applicable","list_type":"list"},{"id":"300213913","category":"ads","ad_impression":"1","list_position":7,"highlight_type":"not applicable","list_type":"list"},{"id":"376897490","category":"ads","ad_impression":"1","list_position":8,"highlight_type":"not applicable","list_type":"list"},{"id":"376843581","category":"ads","ad_impression":"1","list_position":9,"highlight_type":"not applicable","list_type":"list"},{"id":"336948323","category":"ads","ad_impression":"1","list_position":10,"highlight_type":"not applicable","list_type":"list"},{"id":"376769654","category":"ads","ad_impression":"1","list_position":11,"highlight_type":"not applicable","list_type":"list"},{"id":"374196896","category":"ads","ad_impression":"1","list_position":12,"highlight_type":"not applicable","list_type":"list"},{"id":"376769310","category":"ads","ad_impression":"1","list_position":13,"highlight_type":"not applicable","list_type":"list"},{"id":"374921329","category":"ads","ad_impression":"1","list_position":14,"highlight_type":"not applicable","list_type":"list"},{"id":"369141978","category":"ads","ad_impression":"1","list_position":15,"highlight_type":"not applicable","list_type":"list"},{"id":"368363810","category":"ads","ad_impression":"1","list_position":16,"highlight_type":"not applicable","list_type":"list"},{"id":"375788521","category":"ads","ad_impression":"1","list_position":17,"highlight_type":"not applicable","list_type":"list"},{"id":"327971312","category":"ads","ad_impression":"1","list_position":18,"highlight_type":"not applicable","list_type":"list"},{"id":"354262633","category":"ads","ad_impression":"1","list_position":19,"highlight_type":"not applicable","list_type":"list"},{"id":"336121164","category":"ads","ad_impression":"1","list_position":20,"highlight_type":"not applicable","list_type":"list"},{"id":"374986816","category":"ads","ad_impression":"1","list_position":21,"highlight_type":"not applicable","list_type":"list"},{"id":"374295255","category":"ads","ad_impression":"1","list_position":22,"highlight_type":"not applicable","list_type":"list"},{"id ...
#     "Ads": {
#         "Positions": [
#             [
#                 "Middle1",
#                 [
#                     300,
#                     600
#                 ]
#             ],
#             [
#                 "Top1",
#                 [
#                     980,
#                     90
#                 ]
#             ]
#         ],
#         "Page": "milanuncios/parrilla",
#         "Query": {
#             "oasGeoRegion": "",
#             "oasGeoRegionStr": "",
#             "oasCategory": "24"
#         },
#         "Taxonomy": false
#     }
# };</script>
# <script type="text/javascript">
#     (function (a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/schibsted/milanuncios/prod/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
# </script>
# <script src="https://static.milanuncios.com/202012151402-master/js/tracking/tealium_event_publisher.js"></script>
# <script type="text/javascript">
#             visu("0.0.0.0");
#                                     window.onscroll = function () {
#                 if (esmipri) {var thumbnail_245574293 = 'https://img.milanuncios.com/fp/2455/74/245574293_3.jpg?VersionId=qZYVB6rxf_P3S8.NJKHbMrfYLYQd.Yn1';var urlFotos_245574293 = [];urlFotos_245574293['0'] = 'https://img.milanuncios.com/fg/2455/74/245574293_3.jpg?VersionId=PSqRmyGL7nU2jwcCBoutY3.yo_6BVcnS';urlFotos_245574293['1'] = 'https://img.milanuncios.com/fg/2455/74/245574293_2.jpg?VersionId=BkvKNp15mW1f.JsiBecQNSVjaP3vEWQe';urlFotos_245574293['2'] = 'https://img.milanuncios.com/fg/2455/74/245574293_1.jpg?VersionId=bX_HLt_079zWb043nKvNeLL7F6D78p_B';renderImages(245574293,1,321,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_245574293, "urlFotos_245574293");ImageStore.addImages(245574293, urlFotos_245574293);var thumbnail_372769202 = 'https://img.milanuncios.com/fp/3727/69/372769202_1.jpg?VersionId=jBTCsLUscbw2_M.LklMftQtQmV..3dNy';var urlFotos_372769202 = [];urlFotos_372769202['0'] = 'https://img.milanuncios.com/fg/3727/69/372769202_1.jpg?VersionId=kYwu1K0DtL4TJ4AI56Fo6edBKhc_WgC3';urlFotos_372769202['1'] = 'https://img.milanuncios.com/fg/3727/69/372769202_5.jpg?VersionId=zQaYpzRejl4FMUYYnd_k7lb1DwVsuOU3';urlFotos_372769202['2'] = 'https://img.milanuncios.com/fg/3727/69/372769202_2.jpg?VersionId=GMpX8Psx71FbmCXTb8MHWekyorRGg2gh';urlFotos_372769202['3'] = 'https://img.milanuncios.com/fg/3727/69/372769202_3.jpg?VersionId=.dzfK0EX81fSC10whwRffDsxq_wlOOXO';urlFotos_372769202['4'] = 'https://img.milanuncios.com/fg/3727/69/372769202_4.jpg?VersionId=Q2Dz0RcwNA1TTy992lStF4YKD7VlwuEZ';urlFotos_372769202['5'] = 'https://img.milanuncios.com/fg/3727/69/372769202_6.jpg?VersionId=.7fIYTWRyufvZ0VTKd7Iyo0_aKq8Me97';urlFotos_372769202['6'] = 'https://img.milanuncios.com/fg/3727/69/372769202_7.jpg?VersionId=NvQ8gJgjc4QOf6GoT9325t3Fz8qJtzrA';urlFotos_372769202['7'] = 'https://img.milanuncios.com/fg/3727/69/372769202_8.jpg?VersionId=fOB6rMMNM6WTlWmKYGDorKd3z_2uLwIV';urlFotos_372769202['8'] = 'https://img.milanuncios.com/fg/3727/69/372769202_9.jpg?VersionId=.CU3PZuiDk01HXgE..UrTmPTudpAuAJP';renderImages(372769202,1,152346789,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_372769202, "urlFotos_372769202");ImageStore.addImages(372769202, urlFotos_372769202);var thumbnail_300213913 = 'https://img.milanuncios.com/fp/3002/13/300213913_1.jpg?VersionId=iSJPyGwaqa9JqB7wDL3oZU3gAYqHKVk4';var urlFotos_300213913 = [];urlFotos_300213913['0'] = 'https://img.milanuncios.com/fg/3002/13/300213913_1.jpg?VersionId=PPrpL.7_8D8oLaDdWpkucYO.BvuD7AaV';urlFotos_300213913['1'] = 'https://img.milanuncios.com/fg/3002/13/300213913_4.jpg?VersionId=cF8rMzkmAM73r1BHThy3kgBz1OlTXbTY';urlFotos_300213913['2'] = 'https://img.milanuncios.com/fg/3002/13/300213913_3.jpg?VersionId=kwlfE5m1weTiSKrUJE80SEnaW74Ia_m7';urlFotos_300213913['3'] = 'https://img.milanuncios.com/fg/3002/13/300213913_5.jpg?VersionId=mkmotasWaFl2PiJrq2Y6cABUrAglUuJk';urlFotos_300213913['4'] = 'https://img.milanuncios.com/fg/3002/13/300213913_8.jpg?VersionId=cEBIO3mRwLfBx_gklpx2nTf5ijpE5e5Q';urlFotos_300213913['5'] = 'https://img.milanuncios.com/fg/3002/13/300213913_6.jpg?VersionId=JfbmAqol5NRP7E7CIOFROZmQ5vQOySfN';urlFotos_300213913['6'] = 'https://img.milanuncios.com/fg/3002/13/300213913_9.jpg?VersionId=rHEkpYqadJk9fu1wlMTgt4cYplZtndyu';renderImages(300213913,1,1435869,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_300213913, "urlFotos_300213913");ImageStore.addImages(300213913, urlFotos_300213913);var thumbnail_376897490 = 'https://img.milanuncios.com/fp/3768/97/376897490_1.jpg?VersionId=y_CLnfA6anURpC.p4IF4zNeojVWhkUB2';var urlFotos_376897490 = [];urlFotos_376897490['0'] = 'https://img.milanuncios.com/fg/3768/97/376897490_1.jpg?VersionId=xqMbQIVstOkEQwPWJW2kh1x3GvYUCV8y';urlFotos_376897490['1'] = 'https://img.milanuncios.com/fg/3768/97/376897490_2.jpg?VersionId=PnOMzlXnoof9uARBpoiFsotyeL5Xgsud';urlFotos_376897490['2'] = 'https://img.milanuncios.com/fg/3768/97/37689749 ...
#                 }
#                 if (esmipri2 && (document.documentElement.scrollTop > 2000 || document.body.scrollTop > 2000 || window.scrollY > 2000)) {var thumbnail_374921329 = 'https://img.milanuncios.com/fp/3749/21/374921329_1.jpg?VersionId=wHJ01LOhfC_7tzY3CzQvgC5NuijID1qP';var urlFotos_374921329 = [];urlFotos_374921329['0'] = 'https://img.milanuncios.com/fg/3749/21/374921329_1.jpg?VersionId=9gBwSQtl1bSs7gWqNZh6txc3i74GkiRt';urlFotos_374921329['1'] = 'https://img.milanuncios.com/fg/3749/21/374921329_2.jpg?VersionId=WC4JDNCVu2RYYb1w1VqInW6jJCBfEnBL';urlFotos_374921329['2'] = 'https://img.milanuncios.com/fg/3749/21/374921329_3.jpg?VersionId=QneokGnqW6fB93Y0Oe3sRKctqvlnQNrs';urlFotos_374921329['3'] = 'https://img.milanuncios.com/fg/3749/21/374921329_4.jpg?VersionId=TCnSrT4.V45aFSXdNLl2gUqU3bICGaqf';urlFotos_374921329['4'] = 'https://img.milanuncios.com/fg/3749/21/374921329_5.jpg?VersionId=NjrNf.7y7p7c.lNfVL.FVLyJKvzkuXkK';urlFotos_374921329['5'] = 'https://img.milanuncios.com/fg/3749/21/374921329_6.jpg?VersionId=qR1tZ_s1rqV0ej5PSVAD0m81S.gBkI84';renderImages(374921329,1,123456,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_374921329, "urlFotos_374921329");ImageStore.addImages(374921329, urlFotos_374921329);var thumbnail_369141978 = 'https://img.milanuncios.com/fp/3691/41/369141978_1.jpg?VersionId=myYEpswF__hCfnc1WmO3h.cfN3zI9fHE';var urlFotos_369141978 = [];urlFotos_369141978['0'] = 'https://img.milanuncios.com/fg/3691/41/369141978_1.jpg?VersionId=PB51FnGmXnMetWcDjxJbbMoeRgD4OAhN';urlFotos_369141978['1'] = 'https://img.milanuncios.com/fg/3691/41/369141978_2.jpg?VersionId=3VjaQiOcWV2.ozq3T3ogG3w0M3J3WbNq';urlFotos_369141978['2'] = 'https://img.milanuncios.com/fg/3691/41/369141978_3.jpg?VersionId=yVB3PFdlMQafqtiWefewsQXZSHL4Rgg7';urlFotos_369141978['3'] = 'https://img.milanuncios.com/fg/3691/41/369141978_4.jpg?VersionId=jCDhpsSUBi1.j7JQCbo5RqRHa4POw0jg';urlFotos_369141978['4'] = 'https://img.milanuncios.com/fg/3691/41/369141978_5.jpg?VersionId=B6JsWK7yuUOdTxNYsAc8tiJYqGrs43W5';urlFotos_369141978['5'] = 'https://img.milanuncios.com/fg/3691/41/369141978_6.jpg?VersionId=nZRDBjrbdnwZG8GnAMJ4D4GZ3ePD_uCa';urlFotos_369141978['6'] = 'https://img.milanuncios.com/fg/3691/41/369141978_7.jpg?VersionId=Oi5lI8s7oVjq337.r1mbBlBa4dp1dgs_';renderImages(369141978,1,1234567,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_369141978, "urlFotos_369141978");ImageStore.addImages(369141978, urlFotos_369141978);var thumbnail_368363810 = 'https://img.milanuncios.com/fp/3683/63/368363810_1.jpg?VersionId=cj5WGXcXmcJ8yhc8In2pq8.vQnJijavJ';var urlFotos_368363810 = [];urlFotos_368363810['0'] = 'https://img.milanuncios.com/fg/3683/63/368363810_1.jpg?VersionId=w7adafwlM9uV9BXgGQOfsEVxxOe0nj8a';urlFotos_368363810['1'] = 'https://img.milanuncios.com/fg/3683/63/368363810_2.jpg?VersionId=O23btkuPz049QP.EwkWeCVZahWe5MIbJ';urlFotos_368363810['2'] = 'https://img.milanuncios.com/fg/3683/63/368363810_3.jpg?VersionId=uGqzep3O7EEAh.90eThUrYrWStirqqB1';urlFotos_368363810['3'] = 'https://img.milanuncios.com/fg/3683/63/368363810_4.jpg?VersionId=YPnYQ973cCT8IF1sxIi_T4qqvo.9faIG';urlFotos_368363810['4'] = 'https://img.milanuncios.com/fg/3683/63/368363810_5.jpg?VersionId=526H3BS3Da4_KbA1lz0fglR8CsMAPD2N';urlFotos_368363810['5'] = 'https://img.milanuncios.com/fg/3683/63/368363810_6.jpg?VersionId=s8QC_wemUiJ3dVf7NaIPJypWKuZiWrq_';urlFotos_368363810['6'] = 'https://img.milanuncios.com/fg/3683/63/368363810_7.jpg?VersionId=eABa4z9H24QjHPsxrlQvmP.zEjG9Rebs';urlFotos_368363810['7'] = 'https://img.milanuncios.com/fg/3683/63/368363810_8.jpg?VersionId=lDdH.800oUQRJWOjsw.57q_NKDk2C_k5';urlFotos_368363810['8'] = 'https://img.milanuncios.com/fg/3683/63/368363810_9.jpg?VersionId=9nb_.n48HQhJx85IJCDwIPL.PrXNcmYD';renderImages(368363810,1,123456789,'https://static.milanuncios.com/202012151402-master','https://img.milanuncios.com/',thumbnail_368363810, "urlFotos_368363810");ImageStore.addImages(368363810, urlFotos_368 ...
#                 }
#             };
#             var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-4417988-1']);
# _gaq.push(['_setCustomVar', 1, 'seccion', 'motor', 3]);
# _gaq.push(['_setCustomVar', 3, 'provincia', '', 3]);
# _gaq.push(['_trackPageview','/motos-de-carretera/duke-390.htm']);
# _gaq.push(['b._setAccount', 'UA-4417988-2']);
# _gaq.push(['b._trackPageview']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# })();
#         </script>
# <script charset="UTF-8" defer="" id="sui-widget" src="//scm-milanuncios-frontend-pro.milanuncios.com/widgets/downloader.js"></script>
# </div>
# <script defer="" src="/librarym.js"></script>
# </body>
# </html>

# %% [markdown]
# #### SOS: ¡me han baneado!
#
# Si estamos haciendo esto en clase, es muy probable que a la mayoría, nos detecten como bots y nos baneen. Esto pasa porque somos 30 o 40 personas, haciendo la misma petición desde la misma IP y con el mismo user agent.
#
# Puedes usar el html offline que hay en `dat` para seguir con el ejercicio. Descomenta el siguiente código y sigue adelante

# %%
# Descomenta esto si te han baneado
# with open('dat/milanuncios.html') as f:
#     soup = BeautifulSoup(f, 'html.parser')

# %% [markdown]
# Sobre esto, podemos hacer búsquedas con `find` y `find_all` (o `select_one` y `select` si prefieres utilizar [selectores css](https://en.wikipedia.org/wiki/Cascading_Style_Sheets#Selector)). Sobre nuestro ejemplo, vamos a buscar todos los precios. Examinando el código fuente, vemos que son etiquetas `div` con clase `aditem-price`.

# %%
div_precios = soup.find_all('div', class_='aditem-price') # Para saber que tenemos coger <div> y esa clase, primero inspeccionamos
# los precios de idealista y miramos que, efectivamente, estas tabs y clase se usan en los precios normalmente. Vamos probando.
div_precios

# El objetivo al final es filtrar los tabs de html que contengan la información que nos interesa de la web. 
# Obsérvese que soup.find_all te devuelve una lista.
# Out:
# [<div class="aditem-price">4.800<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">4.500<sup>€</sup></div>,
#  <div class="aditem-price">3.850<sup>€</sup></div>,
#  <div class="aditem-price">1.000<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">2.900<sup>€</sup></div>,
#  <div class="aditem-price">3.599<sup>€</sup></div>,
#  <div class="aditem-price">4.700<sup>€</sup></div>,
#  <div class="aditem-price">2.800<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>,
#  <div class="aditem-price">2.250<sup>€</sup></div>,
#  <div class="aditem-price">3.850<sup>€</sup></div>,
#  <div class="aditem-price">4.200<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">3.900<sup>€</sup></div>,
#  <div class="aditem-price">2.900<sup>€</sup></div>,
#  <div class="aditem-price">4.500<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">2.800<sup>€</sup></div>,
#  <div class="aditem-price">4.900<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">2.850<sup>€</sup></div>,
#  <div class="aditem-price">3.999<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">4.200<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.399<sup>€</sup></div>]

# %% [markdown]
# `find_all` devuelve una __lista__ de elementos. Sobre ellos, podemos hacer:
#
# `children` para sacar el listado de todos los hijos.

# %%
div_precios[0].children

# %%
list(div_precios[0].children) # children es un iterable (por eso hay que pasarlo a lista), 
# pero es lo que nos separa los valores que hemos extraído previamente con Beatifulsoup.
# Out:
# ['4.800', <sup>€</sup>]

# %% [markdown]
# `get_text()` para sacar el texto de todos los hijos

# %%
div_precios[0].get_text() # Deja fuera los tabs como <sup>.
# Out:
# '4.800€'

# %% [markdown]
# Por tanto, para sacar el listado de todos los precios podemos hacer:

# %%
mi_lista=[]

for elemento in div_precios:

  mi_lista.append(list(elemento.children)[0])

mi_lista
# Out:
# ['4.800',
#  '3.500',
#  '4.500',
#  '3.850',
#  '1.000',
#  '3.600',
#  '2.900',
#  '3.599',
#  '4.700',
#  '2.800',
#  '3.400',
#  '2.250',
#  '3.850',
#  '4.200',
#  '3.000',
#  '3.900',
#  '2.900',
#  '4.500',
#  '3.400',
#  '3.000',
#  '2.800',
#  '4.900',
#  '3.600',
#  '2.850',
#  '3.999',
#  '3.500',
#  '3.000',
#  '4.200',
#  '3.500',
#  '3.399']

# %% [markdown]
# Esto último se puede reducir a la siguiente línea:

# %%
[list(div_precio.children)[0] for div_precio in div_precios]
# Out:
# ['4.800',
#  '3.500',
#  '4.500',
#  '3.850',
#  '1.000',
#  '3.600',
#  '2.900',
#  '3.599',
#  '4.700',
#  '2.800',
#  '3.400',
#  '2.250',
#  '3.850',
#  '4.200',
#  '3.000',
#  '3.900',
#  '2.900',
#  '4.500',
#  '3.400',
#  '3.000',
#  '2.800',
#  '4.900',
#  '3.600',
#  '2.850',
#  '3.999',
#  '3.500',
#  '3.000',
#  '4.200',
#  '3.500',
#  '3.399']

# %% [markdown]
# Tienes más funciones útiles con pequeños ejemplos [aquí](http://akul.me/blog/2016/beautifulsoup-cheatsheet/)

# %% [markdown]
# ### Ejercicio
#
# Crea un dataframe de pandas en el que cada fila sea un anuncio y tenga como columnas información que consideres relevante: precio, kilómetros, año, cilindrada, texto del anuncio, ...

# %%
import pandas as pd
import numpy as np
import requests

# %%
df_anuncios = pd.DataFrame()
url = 'https://www.milanuncios.com/motos-de-carretera/duke-390.htm'
page = requests.get(url, headers = headers)
page
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Encontramos los anuncios y los inspeccionamos. No podemos coger los primeros niveles tras el cuerpo, pero justo en el nivel 
# inferior hay etiquetas que parecen más generales, así que las usamos.

clase_anuncio ='aditem-detail-image-container' # Hemos cogido uno que no es del todo general, un poco por las prisas.
 
anuncios = soup.find_all('div', class_= clase_anuncio)
primer_anuncio = anuncios[0]
primer_anuncio.find('div', class_ = 'aditem-price').get_text() # Vamos inspeccionando que clase corresponde al precio.
primer_anuncio.find('a', class_ = 'aditem-detail-title').get_text() # Igual con el título del anuncio.
primer_anuncio.find('div', class_='ano tag-mobile').get_text() # Año
# Out:
# 'año 2019'

# %%
for elemento in anuncios:
    Titulo = elemento.find('a', class_='aditem-detail-title').get_text()
    Precio = elemento.find('div', class_='aditem-price').get_text()
    Ano = elemento.find('div', class_='ano tag-mobile').get_text() # Nos da un error porque hay un dato vacío. 
                                                                   #Hay dos formas de resolverlo.
    print(Precio)
# Out:
# 4.800€
# 3.500€
# 4.500€
# 3.850€
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a8231027ccb0> in <module>
#       2     Titulo = elemento.find('a', class_='aditem-detail-title').get_text()
#       3     Precio = elemento.find('div', class_='aditem-price').get_text()
# ----> 4     Ano = elemento.find('div', class_='ano tag-mobile').get_text() # Nos da un error porque hay un dato vacío.
#       5                                                                    #Hay dos formas de resolverlo.
#       6     print(Precio)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
for elemento in anuncios:

 # titulo = elemento.find('a', class_='aditem-detail-title').get_text()

 # precio = elemento.find('div', class_='aditem-price').get_text()

  year = elemento.find('div', class_='ano tag-mobile')

  if year is not None:

    year = year.get_text()

  else:

    year = np.nan

  print(year)

# Vemos que había dos años vacíos (donde no se especificaba el año)
# Out:
# año 2019
# año 2014
# año 2019
# año 2016
# nan
# año 2015
# año 2006
# año 2015
# año 2016
# año 2015
# año 2016
# año 2018
# año 2017
# año 2017
# año 2014
# año 2015
# año 2018
# año 2016
# año 2009
# año 2014
# año 2020
# año 2016
# año 2014
# año 2018
# año 2013
# año 2015
# año 2018
# año 2016
# año 2014

# %%
df_anuncios = pd.DataFrame() # Para que siempre se reinicie el dataframe si resulta que le damos dos veces al for sin querer,
# Si no hiciéramos esto, la segunda vez se volverían a añadir los datos a la tabla por segunda vez.

for elemento in anuncios:
    fila = pd.Series() # Un panda series es una fila con un índice y un objeto, se podría hacer también con un pandas df, pero 
                       # podría dar algún problema.

    titulo = elemento.find('a', class_='aditem-detail-title').get_text()

    precio = elemento.find('div', class_='aditem-price').get_text()

    year = elemento.find('div', class_='ano tag-mobile')

    if year is not None:

      year = year.get_text()

    else:

      year = np.nan
        
    fila['titulo_anuncio'] = titulo
    fila['precio'] = precio
    fila['anyo'] = year
    
    # Solo queda ir metiendo esto como filas al dataframe de anuncios.
    
    df_anuncios =df_anuncios.append(fila,ignore_index=True)

df_anuncios
# Out:
# <ipython-input-20-8eafca74a7b6>:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   fila = pd.Series() # Un panda series es una fila con un índice y un objeto, se podría hacer también con un pandas df, pero
#         anyo  precio                            titulo_anuncio
# 0   año 2019  4.800€                                 KTM - 390
# 1   año 2014  3.500€                        KTM - KTM DUKE 390
# 2   año 2019  4.500€                                KTM - DUKE
# 3   año 2016  3.850€                        KTM - DUKE 390 ABS
# 4        NaN  1.000€  SE COMPRAN MOTOCICLETAS HONDA YAMAHA KAW
# 5   año 2015  3.600€                            KTM - DUKE 390
# 6   año 2006  2.900€                   SUZUKI - GSR 600  NAKED
# 7   año 2015  3.599€                        KTM - DUKE 390 ABS
# 8   año 2016  2.800€                            KTM - DUKE 390
# 9   año 2015  3.400€                            KTM - DUKE 390
# 10  año 2016  2.250€                            KTM - DUKE 390
# 11  año 2018  3.850€                            KTM - DUKE 390
# 12  año 2017  4.200€                            KTM - 390 DUKE
# 13  año 2017  3.000€                            KTM - DUKE 390
# 14  año 2014  3.900€                            KTM - 390 DUKE
# 15  año 2015  2.900€                            KTM - DUKE 390
# 16  año 2018  4.500€                            KTM - 390 DUKE
# 17  año 2016  3.400€                       KTM - 390 DUKE 2016
# 18  año 2009  3.000€                              SUZUKI - GSR
# 19  año 2014  2.800€                        KTM - KMT DUKE 390
# 20  año 2020  4.900€                            KTM - 390 DUKE
# 21  año 2016  3.600€                            KTM - 390 DUKE
# 22  año 2014  2.850€                            KTM - DUKE 390
# 23  año 2018  3.999€                              KTM - RC 390
# 24  año 2013  3.500€                            KTM - DUKE 390
# 25  año 2015  3.000€                        KTM - DUKE 390 ABS
# 26  año 2018  4.200€                            KTM - DUKE 390
# 27  año 2016  3.500€                            KTM - DUKE 390
# 28  año 2014  3.399€                            KTM - DUKE 390

# %% [markdown]
# "Ahora ponedme los precios como floats."

# %%
df_anuncios['precio'][0].replace('€','').replace('.','') # Ya sabemos como dejar los datos de tal forma que los podamos castear
# a floats.
# Out:
# '4800'

# %%
# Aplicándolo al dataframe completo:
df_anuncios['precio_num'] = df_anuncios.apply(lambda row: float(row['precio'].replace('€','').replace('.','')), axis=1)
# Aplicándolo solamente sobre la columna precio:
df_anuncios['precio_num'] = df_anuncios['precio'].apply(lambda x: float(x.replace('€','').replace('.','')))
# En este último caso, como actuamos sobre una serie, no tiene ejes (no ponemos axis).
# Comprobemos si el tipo es, en efecto, float:
df_anuncios.dtypes
# Out:
# anyo               object
# precio             object
# titulo_anuncio     object
# precio_num        float64
# dtype: object

# %% [markdown]
# ### Ejercicio
#
# Modifica el código anterior para que, además de bajarse la página actual, navegue por el resto de páginas e incorpore también esos anuncios a tu dataframe.

# %% [markdown]
# ## Scraping de tablas
#
# (__leer en casa__)
#
# A menudo, la información que nos interesa descargar está en tablas y nuestro objetivo es importarlas en tablas de Pandas. Esta conversión suele exigir la manipulación del texto, números y fechas contenidas en la tabla original, lo que nos obligará a repasar cómo realizar esas operaciones y aplicarlas a filas y columnas de las tablas.
#
# La estructura que suelen tener la tablas en `html` es:
#
# ```
# <table>
#     <thead>
#         <tr>
#             <th>Columna A</th>
#             <th>Columna B</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A1</td>
#             <td>B1</td>
#         </tr>
#         <tr>
#             <td>A2</td>
#             <td>B2</td>
#         </tr>
#     </tbody>
# </table>
# ```

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Columna A</th>
#             <th>Columna B</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A1</td>
#             <td>B1</td>
#         </tr>
#         <tr>
#             <td>A2</td>
#             <td>B2</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Necesitaremos los siguientes módulos además de `requests` y `BeautifulSoup` importados anteriormente:

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Primero, hacemos una petición para descargar la página de interés (que contiene las cotizaciones de las acciones del IBEX 35 en tiempo _casi_ real).

# %%
base_url = "https://www.eleconomista.es/indice/IBEX-35"
res = requests.get(base_url)
contenido = res.content

# %% [markdown]
# La siguiente línea procesa el HTML de la página que hemos descargado:

# %%
soup = BeautifulSoup(contenido, "html.parser")

# %% [markdown]
# Una vez procesado el HTML, es posible buscar elementos dentro de él. En particular, podemos buscar los elementos de tipo `table`, es decir, tablas.

# %%
tablas = soup.find_all('table') # Buscamos primero todas las tablas de la web, que llevan el tag <table>.

# %% [markdown]
# El objeto `tablas` contiene todas las tablas presentes en la página. Hay que tener cuidado con dichas tablas porque muchas páginas utilizan elementos de tipo `table` para estructurar el contenido. Por eso, en algunas páginas, aunque parezca haber una única tabla, puede haber otras con una información no interesante que toca descartar.

# %%
len(tablas) # Podemos comprobar que hemos traído solo 3 tablas, que es lo que nos interesa. Aunque para asegurar lo suyo es 
            # añadir una class_.
# Out:
# 3

# %%
# Si quisiéramos solo la primera tabla, como ya podemos tratar el contenido como una lista, podemos hacer:

mi_tabla = tablas[0]

# %%
mi_tabla.find('thead') # Sabemos que solo hay un encabezado para cada tabla, así que usamos .find() para encontrarlo.
# Out:
# <thead><tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr></thead>

# %%
mi_tabla.find('thead').find('tr').find_all('th') # Vamos filtrando hasta llegar al th, que es donde está la información.

# Realmente, el find('tr') aquí es prescindible, podemos saltar al 'th' directamente porque no hay varios en el 'tr'.
# Out:
# [<th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th>,
#  <th>Precio</th>,
#  <th data-breakpoints="" data-title=""></th>,
#  <th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th>,
#  <th data-breakpoints="xs">Var. (€)</th>,
#  <th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th>,
#  <th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th>,
#  <th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th>,
#  <th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th>,
#  <th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th>]

# %% [markdown]
# ----------------- A PARTIR DE AQUÍ LO HECHO EN CLASE (EQUIVALENTE A LO QUE SE HACE MÁS TARDE) -------------------------------

# %%
list()
# Out:
# []

# %%
col_df = list() # Es equivalente a escribir [].

for elemento in mi_tabla.find('thead').find_all('th'):
    col_df.append(elemento.get_text())
col_df
# Out:
# ['Nombre',
#  'Precio',
#  '',
#  'Var. (%)',
#  'Var. (€)',
#  'Volumen (€)',
#  'Capitalización(1)',
#  'PER',
#  'Rent. /Div.',
#  ' Hora ']

# %%
mi_tabla.find('tbody').find_all('tr')[0].find_all('td') 

# Hay un solo tbody por cada tabla (normalmente), luego, dentro de cada 
# 'tr' (table row) hay varios elementos que, si dejamos así, nos los va a dar todos juntos en un string por cada fila. Por lo 
# tanto, para cada fila hay que volver a hacer un find_all('td'), que nos saque todos los 'td' por cada fila (cada 'td' contiene
# un elemento de la fila, así que así estamos obteniendo un string para cada elemento de cada fila).

# Nos hace falta un bucle para ir ejecutando la línea sobre cada fila ('tr').
# Out:
# [<td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a></td>,
#  <td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">109,70</span></td>,
#  <td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td>,
#  <td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,37%</span></td>,
#  <td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,40</span></td>,
#  <td><span>11.564.875,70</span></td>,
#  <td>0,00</td>,
#  <td>33,29</td>,
#  <td>1,80%</td>,
#  <td><span class="footable-last-visible">16:28</span></td>]

# %%
filas_df = list()

for fila in mi_tabla.find('tbody').find_all('tr'):
    fila_actual = list()
    for elemento in fila.find_all('td'):
        fila_actual.append(elemento.get_text())
    filas_df.append(fila_actual)
        
filas_df
# 4ptos LEER, MOD, df + df WS (JOINs)
# 4ptos df pd -> Operaciones con matrices. Gestión de excepciones (Try).
# 3ptos Llamar API y trabajar con eso.
# Suma 11.
# Out:
# [['ACCIONA',
#   '109,70',
#   '',
#   '+0,37%',
#   '0,40',
#   '11.564.875,70',
#   '0,00',
#   '33,29',
#   '1,80%',
#   '16:28'],
#  ['ACERINOX',
#   '9,02',
#   '',
#   '+2,99%',
#   '0,26',
#   '10.584.347,42',
#   '0,00',
#   '38,38',
#   '5,73%',
#   '16:28'],
#  ['ACS',
#   '26,87',
#   '',
#   '+1,32%',
#   '0,35',
#   '9.670.958,24',
#   '0,00',
#   '13,27',
#   '5,90%',
#   '16:28'],
#  ['AENA',
#   '136,20',
#   '',
#   '+0,22%',
#   '0,30',
#   '8.129.301,00',
#   '0,00',
#   '14,16',
#   '0,00%',
#   '16:28'],
#  ['ALMIRALL',
#   '10,96',
#   '',
#   '+1,48%',
#   '0,16',
#   '5.813.591,60',
#   '0,00',
#   '22,79',
#   '1,82%',
#   '16:27'],
#  ['AMADEUS',
#   '58,94',
#   '',
#   '-1,64%',
#   '-0,98',
#   '25.791.824,38',
#   '0,00',
#   '20,41',
#   '0,00%',
#   '16:27'],
#  ['ARCELORMITTAL',
#   '18,33',
#   '',
#   '+5,50%',
#   '0,96',
#   '13.917.643,30',
#   '0,00',
#   '0,00',
#   '0,00%',
#   '16:27'],
#  ['BANKIA',
#   '1,55',
#   '',
#   '+1,98%',
#   '0,03',
#   '3.873.744,99',
#   '0,00',
#   '53,19',
#   '0,00%',
#   '16:28'],
#  ['BANKINTER',
#   '4,47',
#   '',
#   '+1,00%',
#   '0,04',
#   '38.707.958,57',
#   '0,00',
#   '15,05',
#   '2,06%',
#   '16:28'],
#  ['BBVA',
#   '4,06',
#   '',
#   '+0,87%',
#   '0,04',
#   '31.105.922,48',
#   '0,00',
#   '10,18',
#   '0,76%',
#   '16:28']]

# %%
df_Datos = pd.DataFrame(filas_df, columns=col_df)
df_Datos
# Out:
#           Nombre  Precio   Var. (%) Var. (€)    Volumen (€) Capitalización(1)  \
# 0        ACCIONA  109,70     +0,37%     0,40  11.564.875,70              0,00
# 1       ACERINOX    9,02     +2,99%     0,26  10.584.347,42              0,00
# 2            ACS   26,87     +1,32%     0,35   9.670.958,24              0,00
# 3           AENA  136,20     +0,22%     0,30   8.129.301,00              0,00
# 4       ALMIRALL   10,96     +1,48%     0,16   5.813.591,60              0,00
# 5        AMADEUS   58,94     -1,64%    -0,98  25.791.824,38              0,00
# 6  ARCELORMITTAL   18,33     +5,50%     0,96  13.917.643,30              0,00
# 7         BANKIA    1,55     +1,98%     0,03   3.873.744,99              0,00
# 8      BANKINTER    4,47     +1,00%     0,04  38.707.958,57              0,00
# 9           BBVA    4,06     +0,87%     0,04  31.105.922,48              0,00
#
#      PER Rent. /Div.  Hora
# 0  33,29       1,80%  16:28
# 1  38,38       5,73%  16:28
# 2  13,27       5,90%  16:28
# 3  14,16       0,00%  16:28
# 4  22,79       1,82%  16:27
# 5  20,41       0,00%  16:27
# 6   0,00       0,00%  16:27
# 7  53,19       0,00%  16:28
# 8  15,05       2,06%  16:28
# 9  10,18       0,76%  16:28

# %%
# Otra forma:

df_Datos2 = pd.DataFrame(filas_df)
df_Datos2.columns = col_df
df_Datos2
# Out:
#           Nombre  Precio   Var. (%) Var. (€)    Volumen (€) Capitalización(1)  \
# 0        ACCIONA  109,70     +0,37%     0,40  11.564.875,70              0,00
# 1       ACERINOX    9,02     +2,99%     0,26  10.584.347,42              0,00
# 2            ACS   26,87     +1,32%     0,35   9.670.958,24              0,00
# 3           AENA  136,20     +0,22%     0,30   8.129.301,00              0,00
# 4       ALMIRALL   10,96     +1,48%     0,16   5.813.591,60              0,00
# 5        AMADEUS   58,94     -1,64%    -0,98  25.791.824,38              0,00
# 6  ARCELORMITTAL   18,33     +5,50%     0,96  13.917.643,30              0,00
# 7         BANKIA    1,55     +1,98%     0,03   3.873.744,99              0,00
# 8      BANKINTER    4,47     +1,00%     0,04  38.707.958,57              0,00
# 9           BBVA    4,06     +0,87%     0,04  31.105.922,48              0,00
#
#      PER Rent. /Div.  Hora
# 0  33,29       1,80%  16:28
# 1  38,38       5,73%  16:28
# 2  13,27       5,90%  16:28
# 3  14,16       0,00%  16:28
# 4  22,79       1,82%  16:27
# 5  20,41       0,00%  16:27
# 6   0,00       0,00%  16:27
# 7  53,19       0,00%  16:28
# 8  15,05       2,06%  16:28
# 9  10,18       0,76%  16:28

# %% [markdown]
# ----------------- A PARTIR DE AQUÍ CONTINÚA LO QUE VENÍA HECHO DESDE EL PRINCIPIO EN EL NOTEBOOK -------------------------------

# %% [markdown]
# Podemos extraer las filas de todas estas tablas

# %%
# todas_las_lineas = []
# for tabla in tablas:
#     lineas_tabla = tabla.find_all('tr') # Dentro de cada una de las 3 tablas, va a encontrar las filas (contienen el tab 'tr')
#     for x in lineas_tabla:              # Cada fila que haya encontrado en cada tabla...
#         todas_las_lineas.append(x)      # es añadida a la lista vacía creada al principio.

# %%
lineas = [x for tabla in tablas for x in tabla.find_all('tr')] # Forma simplificada.

# %% [markdown]
# para luego extraer los contenidos de cada fila individualmente haciendo

# %%
# datos=[]
# for linea in lineas:
#     linea_datos =[]
#     for x in linea.find_all('td'):
#         linea_datos.append(x.get_text())
#     datos.append(linea_datos)

# %%
datos = [[x.text for x  in linea.find_all('td')] for linea in lineas] # Forma simplificada.Es como hacer el bucle de dcha. a izq.

# %% [markdown]
# Podemos inspeccionar parte del objeto resultante:

# %%
datos[0:3]
# Out:
# [[],
#  ['ACCIONA',
#   '108,70',
#   '',
#   '-3,81%',
#   '-4,30',
#   '256.057.352,65',
#   '0,00',
#   '32,77',
#   '1,83%',
#   '11/12'],
#  ['ACERINOX',
#   '8,72',
#   '',
#   '-0,73%',
#   '-0,06',
#   '4.965.966,67',
#   '0,00',
#   '39,62',
#   '5,55%',
#   '11/12']]

# %% [markdown]
# Vemos que hay filas que contienen la información de interés junto con otras que contienen cabeceras y otra información irrelevante. En general, la situación puede ser más complicada y se hace necesario estudiar el objeto `tablas` para seleccionar la de interés.
#
# En nuestro caso, podemos filtrar las líneas menos relevantes así:

# %%
datos = [x for x in datos if len(x) > 0]

# %% [markdown]
# Finalmente, podemos crear una tabla de Pandas:

# %%
datos = pd.DataFrame(datos)
datos
# Out:
#                     0       1 2       3      4               5     6        7  \
# 0             ACCIONA  108,70    -3,81%  -4,30  256.057.352,65  0,00    32,77
# 1            ACERINOX    8,72    -0,73%  -0,06    4.965.966,67  0,00    39,62
# 2                 ACS   26,68    +0,57%   0,15   16.770.073,52  0,00    13,69
# 3                AENA  136,10     0,00%   0,00   53.106.925,10  0,00    14,76
# 4            ALMIRALL   10,71    -0,74%  -0,08    3.280.992,98  0,00    22,77
# 5             AMADEUS   60,22    -1,60%  -0,98   47.875.274,20  0,00    21,69
# 6       ARCELORMITTAL   17,19    -1,37%  -0,24    6.467.938,75  0,00     0,00
# 7              BANKIA    1,50    -1,64%  -0,03    5.878.101,65  0,00    54,15
# 8           BANKINTER    4,26    -2,38%  -0,10   16.062.250,86  0,00    15,81
# 9                BBVA    3,97    -2,05%  -0,08  164.534.116,93  0,00    11,04
# 10          CAIXABANK    2,20    -1,79%  -0,04   22.459.496,93  0,00    14,88
# 11   CELLNEX TELECOM    51,40    +0,08%   0,04   40.634.893,42  0,00  2683,54
# 12     CIE AUTOMOTIVE   19,91    -1,73%  -0,35    2.107.164,12  0,00    16,97
# 13             ENAGAS   20,11    -1,08%  -0,22   19.640.570,68  0,00    11,72
# 14             ENDESA   22,95    +0,79%   0,18   47.023.685,09  0,00    13,49
# 15          FERROVIAL   22,99    -0,48%  -0,11   20.089.607,94  0,00    67,20
# 16            GRIFOLS   24,11    -1,23%  -0,30   15.836.130,38  0,00    22,77
# 17       IAG (IBERIA)    1,71    -4,26%  -0,08   51.788.921,88  0,00     2,36
# 18          IBERDROLA   11,25    -0,44%  -0,05  102.562.099,61  0,00    19,89
# 19            INDITEX   26,40    -1,20%  -0,32   63.189.554,77  0,00    58,32
# 20              INDRA    6,79    -2,65%  -0,19    3.817.039,41  0,00    46,19
# 21      INM. COLONIAL    8,19    +1,61%   0,13    4.925.297,60  0,00    28,73
# 22             MAPFRE    1,67    -0,71%  -0,01   18.509.023,89  0,00     8,75
# 23  MELIA HOTELS INTL    5,50    -2,83%  -0,16    7.182.481,93  0,00    11,94
# 24       MERLIN PROP.    7,79    -1,83%  -0,15    6.650.846,15  0,00    16,19
# 25            NATURGY   18,90    -0,08%  -0,02   24.639.130,43  0,00    19,00
# 26       PHARMA MAR R   71,40    +0,56%   0,40   11.544.640,90  0,00     0,00
# 27                REE   16,70    -0,48%  -0,08   17.861.849,22  0,00    13,21
# 28             REPSOL    8,78    -1,90%  -0,17   99.032.515,04  0,00    38,92
# 29           SABADELL    0,35    -2,83%  -0,01   18.421.074,40  0,00     2,82
# 30          SANTANDER    2,58    -2,76%  -0,07  256.900.226,05  0,00    11,44
# 31     SIEMENS GAMESA   28,92    +1,01%   0,29   24.529.241,37  0,00    39,63
# 32    SOLARIA ENERGIA   18,89    -0,16%  -0,03    9.390.675,39  0,00   108,82
# 33         TELEFONICA    3,55    -4,21%  -0,16  105.520.225,05  0,00     9,96
# 34           VISCOFAN   58,50    +0,09%   0,05    3.245.601,10  0,00    23,21
#
#          8      9
# 0    1,83%  11/12
# 1    5,55%  11/12
# 2    5,72%  11/12
# 3    0,00%  11/12
# 4    1,82%  11/12
# 5    0,00%  11/12
# 6    0,00%  11/12
# 7    0,00%  11/12
# 8    1,96%  11/12
# 9    0,70%  11/12
# 10   1,87%  11/12
# 11   0,14%  11/12
# 12   2,84%  11/12
# 13   8,48%  11/12
# 14   8,36%  11/12
# 15   3,01%  11/12
# 16   1,58%  11/12
# 17   0,00%  11/12
# 18   3,75%  11/12
# 19   2,31%  11/12
# 20   0,00%  11/12
# 21   2,37%  11/12
# 22   7,02%  11/12
# 23   0,00%  11/12
# 24   5,11%  11/12
# 25   7,52%  11/12
# 26   0,00%  11/12
# 27   6,10%  11/12
# 28  11,68%  11/12
# 29   0,00%  11/12
# 30   3,35%  11/12
# 31   0,00%  11/12
# 32   0,00%  11/12
# 33  10,57%  11/12
# 34   2,92%  11/12

# %% [markdown]
# #### Ejercicio
#
# Usa los elementos `th` de la primera fila de las tablas para extraer nombres para las columnas de la tabla.

# %% [markdown]
# #### Ejercicio
#
# Elimina las columnas irrelevantes y cambia los nombres de las columnas por otros breves y sin caracteres extraños o que dificulten el posproceso.

# %% [markdown]
# #### Ejercicio
#
# Cambia el formato de las columnas adecuadamente: convierte a numéricas, etc., las columnas que lo requieran.

# %% [markdown]
# ## Riesgos del scraping
#
# El scraping es una técnica potente pero tiene varios contras:
#
# * Implica mayor tiempo de desarrollo y mayor esfuerzo en la limpieza de datos (en comparación con otras fuentes como APIs, BDs, ...)
# * Si hay que scrapear gran cantidad de páginas, es lento
# * Los servidores objetivo de nuestro scraping pueden tener técnicas para evitarlo. Por ejemplo, bloquear la IP temporalmente o introducir delays en las respuestas si hacemos muchas peticiones en poco tiempo. Esto pasa especialmente en las grandes webs recelosas de sus datos (p.e. linkedin, amazon, ...).
# * El código de scraping escrito hoy puede no funcionar mañana, si la web destino cambia nombres, etiquetas o estructura. Si se sube a producción para lanzarlo periódicamente, hay que ser conscientes de que en algún momento fallará, y establecer mecanismos de alerta
#
# ## Javascript
#
# Es posible que te encuentres con algún caso en el que no puedas descargar tal cual el html y parsearlo, principalmente por dos motivos:
#
# * La estructura de la página se genera parcial o totalmente en cliente
# * Debemos interactuar con algún elemento para mostrar la información que queremos (p.e. completar un campo de búsuqeda, hacer click en algún botón, ...)
#
# En estos casos, hay que ejecutar en un navegador local el código javascript de la página destino. Para esta tarea, puedes utilizar Selenium.
#
# [Aquí](https://medium.freecodecamp.org/better-web-scraping-in-python-with-selenium-beautiful-soup-and-pandas-d6390592e251) un post con un ejemplo de uso.
